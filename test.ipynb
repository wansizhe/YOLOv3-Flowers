# %%
import numpy as np
import pandas as pd

# %%
label = pd.read_csv('label.csv')
label
# Out:
#       image  label
# 0         0     77
# 1         1     77
# 2         2     77
# 3         3     77
# 4         4     77
# 5         5     77
# 6         6     77
# 7         7     77
# 8         8     77
# 9         9     77
# 10       10     77
# 11       11     77
# 12       12     77
# 13       13     77
# 14       14     77
# 15       15     77
# 16       16     77
# 17       17     77
# 18       18     77
# 19       19     77
# 20       20     77
# 21       21     77
# 22       22     77
# 23       23     77
# 24       24     77
# 25       25     77
# 26       26     77
# 27       27     77
# 28       28     77
# 29       29     77
# ...     ...    ...
# 8159   8159     62
# 8160   8160     62
# 8161   8161     62
# 8162   8162     62
# 8163   8163     62
# 8164   8164     62
# 8165   8165     62
# 8166   8166     62
# 8167   8167     62
# 8168   8168     62
# 8169   8169     62
# 8170   8170     62
# 8171   8171     62
# 8172   8172     62
# 8173   8173     62
# ...

# %%
num = pd.read_csv('num.csv')
num
# Out:
#                         label  num
# 0                     petunia  258
# 1              passion flower  251
# 2                  wallflower  196
# 3                  water lily  194
# 4                  watercress  184
# 5                        rose  171
# 6                  frangipani  166
# 7                    foxglove  162
# 8                   cyclamen   154
# 9                       lotus  137
# 10                   hibiscus  131
# 11                 sword lily  130
# 12              bougainvillea  128
# 13             barbeton daisy  127
# 14                thorn apple  120
# 15                   geranium  114
# 16                   clematis  112
# 17         bishop of llandaff  109
# 18        pink-yellow dahlia?  109
# 19                cape flower  108
# 20              morning glory  107
# 21                  anthurium  105
# 22          californian poppy  102
# 23                     azalea   96
# 24                 poinsettia   93
# 25                    primula   93
# ...

# %%
sum(num['num'])
# Out:
# 8189

# %%
cnts = label['label'].value_counts()

# %%
cnts
# Out:
# 51     258
# 77     251
# 46     196
# 73     194
# 89     184
# 74     171
# 81     166
# 94     162
# 88     154
# 78     137
# 83     131
# 43     130
# 95     128
# 41     127
# 75     120
# 58     114
# 82     112
# 56     109
# 60     109
# 37     108
# 76     107
# 80     105
# 65     102
# 72      96
# 53      93
# 44      93
# 50      92
# 23      91
# 96      91
# 11      87
#       ...
# 64      52
# 61      50
# 49      49
# 19      49
# 15      49
# 13      49
# 100     49
# 14      48
# 102     48
# 33      46
# 93      46
# 9       46
# 10      45
# 32      45
# 6       45
# 35      43
# 24      42
# 67      42
# 79      41
# 16      41
# 25      41
# 26      41
# 39      41
# 45      40
# 34      40
# 27      40
# 21      40
# 7       40
# 1       40
# 3       40
# Name: label, Length: 102, dtype: int64

# %%
temp = num.copy()

# %%
temp = temp.sort_values(by='num', ascending=False)

# %%
temp
# Out:
#                         label  num
# 0                     petunia  258
# 1              passion flower  251
# 2                  wallflower  196
# 3                  water lily  194
# 4                  watercress  184
# 5                        rose  171
# 6                  frangipani  166
# 7                    foxglove  162
# 8                   cyclamen   154
# 9                       lotus  137
# 10                   hibiscus  131
# 11                 sword lily  130
# 12              bougainvillea  128
# 13             barbeton daisy  127
# 14                thorn apple  120
# 15                   geranium  114
# 16                   clematis  112
# 17         bishop of llandaff  109
# 18        pink-yellow dahlia?  109
# 19                cape flower  108
# 20              morning glory  107
# 21                  anthurium  105
# 22          californian poppy  102
# 23                     azalea   96
# 25                    primula   93
# 24                 poinsettia   93
# ...

# %%
type(cnts)
# Out:
# pandas.core.series.Series

# %%
type(temp)
# Out:
# pandas.core.frame.DataFrame

# %%
cnts = pd.DataFrame({'id': cnts.index, 'idnum': cnts.values})

# %%
cnts
# Out:
#       id  idnum
# 0     51    258
# 1     77    251
# 2     46    196
# 3     73    194
# 4     89    184
# 5     74    171
# 6     81    166
# 7     94    162
# 8     88    154
# 9     78    137
# 10    83    131
# 11    43    130
# 12    95    128
# 13    41    127
# 14    75    120
# 15    58    114
# 16    82    112
# 17    56    109
# 18    60    109
# 19    37    108
# 20    76    107
# 21    80    105
# 22    65    102
# 23    72     96
# 24    53     93
# 25    44     93
# 26    50     92
# 27    23     91
# 28    96     91
# 29    11     87
# ..   ...    ...
# 72    64     52
# 73    61     50
# 74    49     49
# 75    19     49
# 76    15     49
# 77    13     49
# 78   100     49
# 79    14     48
# 80   102     48
# 81    33     46
# 82    93     46
# 83     9     46
# 84    10     45
# 85    32     45
# 86     6     45
# 87    35     43
# 88    24     42
# 89    67     42
# 90    79     41
# 91    16     41
# 92    25     41
# 93    26     41
# 94    39     41
# ...

# %%
total = pd.concat([temp, cnts], axis=1)

# %%
total
# Out:
#                         label  num   id  idnum
# 0                     petunia  258   51    258
# 1              passion flower  251   77    251
# 2                  wallflower  196   46    196
# 3                  water lily  194   73    194
# 4                  watercress  184   89    184
# 5                        rose  171   74    171
# 6                  frangipani  166   81    166
# 7                    foxglove  162   94    162
# 8                   cyclamen   154   88    154
# 9                       lotus  137   78    137
# 10                   hibiscus  131   83    131
# 11                 sword lily  130   43    130
# 12              bougainvillea  128   95    128
# 13             barbeton daisy  127   41    127
# 14                thorn apple  120   75    120
# 15                   geranium  114   58    114
# 16                   clematis  112   82    112
# 17         bishop of llandaff  109   56    109
# 18        pink-yellow dahlia?  109   60    109
# ...

# %%
pd.set_option('display.max_rows', None)
total.loc[0:77]
# Out:
#                         label  num   id  idnum
# 0                     petunia  258   51    258
# 1              passion flower  251   77    251
# 2                  wallflower  196   46    196
# 3                  water lily  194   73    194
# 4                  watercress  184   89    184
# 5                        rose  171   74    171
# 6                  frangipani  166   81    166
# 7                    foxglove  162   94    162
# 8                   cyclamen   154   88    154
# 9                       lotus  137   78    137
# 10                   hibiscus  131   83    131
# 11                 sword lily  130   43    130
# 12              bougainvillea  128   95    128
# 13             barbeton daisy  127   41    127
# 14                thorn apple  120   75    120
# 15                   geranium  114   58    114
# 16                   clematis  112   82    112
# 17         bishop of llandaff  109   56    109
# 18        pink-yellow dahlia?  109   60    109
# ...

# %%
total.loc[0:30]
# Out:
#                   label  num  id  idnum
# 0               petunia  258  51    258
# 1        passion flower  251  77    251
# 2            wallflower  196  46    196
# 3            water lily  194  73    194
# 4            watercress  184  89    184
# 5                  rose  171  74    171
# 6            frangipani  166  81    166
# 7              foxglove  162  94    162
# 8             cyclamen   154  88    154
# 9                 lotus  137  78    137
# 10             hibiscus  131  83    131
# 11           sword lily  130  43    130
# 12        bougainvillea  128  95    128
# 13       barbeton daisy  127  41    127
# 14          thorn apple  120  75    120
# 15             geranium  114  58    114
# 16             clematis  112  82    112
# 17   bishop of llandaff  109  56    109
# 18  pink-yellow dahlia?  109  60    109
# 19          cape flower  108  37    108
# 20        morning glory  107  76    107
# 21            anthurium  105  80    105
# ...

# %%
total.to_csv('total.csv')
